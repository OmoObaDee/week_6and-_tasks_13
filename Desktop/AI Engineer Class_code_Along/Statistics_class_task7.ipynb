# %% [markdown]
# #  Question calculate the variance of the values (4,8,6,5,3)
# # Step 1:
# Write the data
#
# x=(4,8,6,5,3)
#
# Number of values = 5 which is (n)
#
# # Step 2:
# Find the mean
#
# mean     = 4+8+6+5+3
#  n             5
#  Meaning we divide total sum of the value = 26/5
#
#
#  Mean is  ​= 5.2
# # Step 3:
# Find deviations from the mean and square them one by one
#
# (4−5.2)2=(−1.2)2    = 1.44
#
#
# (8−5.2)2=(2.8)2      =  7.84
#
#
# (6−5.2)2=(0.8)2       =  0.64
#
#
# (5−5.2)2=(−0.2)2      = 0.04
#
#
# (3−5.2)2=(−2.2)2       =4.8
#
#
# # 4 Next is Squared Deviation Calculation
#
#
# Now we need to add up all the deviation from the mean and square all together
#
#
# 1.44+7.84+0.64+0.04+4.84  = 14.8
#
#
# Meaning squared Deviations is 14.8
#
# # Finally
#
# Step 5: Variance
# Population variance:  σ2   =    14.8 divide by 5
#         Variance is 2.96
#
# Sample variance : to do this we will minus 1 from total number values which is 5
#
#       I.e 5-1 = 4
#
# Therefore : 14.8/4 = 3.7
